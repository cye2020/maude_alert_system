# %% [markdown]
# # 데이터 다운로드 설명

# %% [markdown]
# ## 다운로더 로드

# %%
import sys
from pathlib import Path

# 프로젝트 루트를 sys.path에 추가
project_root = Path.cwd().parent  # code 폴더에서 한 단계 위
print(project_root)
sys.path.append(str(project_root))
sys.path.append(str(project_root / 'code'))

# 이제 import 가능
from loading import DataLoader
loader = DataLoader(
    # start - end 범위의 날짜
    start=2024,
    end=2024,
    # 저장 path
    output_file='temp.parquet',
    # 병렬 작업 (메모리 터지면 줄이고, 빠르게 다운 받고 싶으면 늘리면 됨)
    max_workers=4
)

# %%
# 데이터 로드 방법 결정 (pandas, polars, spark 가능)
adapter = 'pandas'
pandas_kwargs = {
    # 사용 컬럼 지정 가능
    # 'columns': [],
    'engine': 'pyarrow'
}

# %% [markdown]
# ## 처음부터 다운로드

# %%
# 다운로드 및 로드
loader.process(skip=False, adapter=adapter, **pandas_kwargs)

# %% [markdown]
# ## 스키마 수집까지 끝난 경우

# %%
# 다운로드 및 로드
loader.process(skip=True, adapter=adapter, **pandas_kwargs)

# %% [markdown]
# ## 다운로드가 끝난 경우

# %%
df = loader.load(adapter=adapter, **pandas_kwargs)
if df is not None:
    print(f"\n데이터프레임 shape: {df.shape}")
    print(df.head())
# Out:
# 📖 temp.parquet 로딩 중... (adapter=pandas)
#
# 데이터프레임 shape: (2627150, 354)
#   adverse_event_flag date_added date_changed date_facility_aware  \
# 0                  N   20240511     20240616                None
# 1                  N   20240619     20240715                None
# 2                  Y   20240511     20240513                None
# 3                  Y   20240619     20240624            20240617
# 4                  Y   20240511     20240513                None
#
#   date_manufacturer_received date_of_event date_received date_report  \
# 0                   20240411          None      20240511    20240511
# 1                   20240524      20240418      20240619    20240619
# 2                       None      20240401      20240511        None
# 3                       None      20240501      20240619        None
# 4                       None      20230803      20240511        None
#
#   date_report_to_fda date_report_to_manufacturer  ... report_to_manufacturer  \
# ...

# %% [markdown]
# ### To Do
#
# 1. bash에서 실행시킬 때 args 받도록 코드 수정
# 2. yaml 파일에 args 미리 지정
